# %% [markdown]
# OutPut Parsers
#
#   - convert raw LLM responses into structured formats like JSON, CSV, Pydantic models.
#   - ensure consistency, validation and ease of use in application

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate

load_dotenv()
# Out:
# True

# %%
model=ChatOpenAI()

# %%
#1st prompt -> detailed analysis

template1=PromptTemplate(
    input_variables=["topic"],
    template="Provide a detailed analysis of the following text:\n\n{topic}"
)

# %%
#2nd prompt ->summary

template2=PromptTemplate(
    input_variables=["text"],
    template="write a 5 line Summary the following text:\n\n{text}"
)

# %%
prompt1=template1.invoke({"topic":"Artificial Intelligence in Healthcare"})
result=model.invoke(prompt1)

# %%
prompt2=template2.invoke({"text":result})
result2=model.invoke(prompt2)

# %%
print(result2.content)
# Out:
# AI in healthcare is rapidly growing, revolutionizing patient care with tasks like learning and decision-making. It streamlines processes, enhances diagnostics, and personalizes treatment plans. AI analyzes vast data quickly for efficient decision-making and assists in accurate diagnoses. It automates tasks for better healthcare delivery and enhances patient engagement. Ethical guidelines are crucial for responsible AI use to ensure patient safety and trust in transforming healthcare.
