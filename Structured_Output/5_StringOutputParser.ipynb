# %%
pip install -U langchain-core langchain-community langchain
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-core in c:\users\deepak18\appdata\roaming\python\python313\site-packages (1.2.6)
# Collecting langchain-core
#   Downloading langchain_core-1.2.7-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: langchain-community in c:\users\deepak18\appdata\roaming\python\python313\site-packages (0.4.1)
# Requirement already satisfied: langchain in c:\users\deepak18\appdata\roaming\python\python313\site-packages (1.1.3)
# Collecting langchain
#   Downloading langchain-1.2.3-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-core) (0.4.5)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-core) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-core) (2.11.7)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-core) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-core) (4.14.1)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-core) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.10.18)
# Requirement already satisfied: requests<3,>=2 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.23.0)
# Requirement already satisfied: anyio in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (4.9.0)
# Requirement already satisfied: certifi in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2025.7.9)
# Requirement already satisfied: httpcore==1.* in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.9)
# Requirement already satisfied: idna in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from requests<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from requests<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core) (2.3.0)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-community) (2.0.41)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-community) (2.2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: greenlet>=1 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain) (1.0.5)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.3.0)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.3.1)
# Downloading langchain_core-1.2.7-py3-none-any.whl (490 kB)
# Downloading langchain-1.2.3-py3-none-any.whl (106 kB)
# Installing collected packages: langchain-core, langchain
#
#   Attempting uninstall: langchain-core
#
#     Found existing installation: langchain-core 1.2.6
#
#    ---------------------------------------- 0/2 [langchain-core]
#     Uninstalling langchain-core-1.2.6:
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#       Successfully uninstalled langchain-core-1.2.6
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#   Attempting uninstall: langchain
#    ---------------------------------------- 0/2 [langchain-core]
#     Found existing installation: langchain 1.1.3
#    ---------------------------------------- 0/2 [langchain-core]
#    -------------------- ------------------- 1/2 [langchain]
#     Uninstalling langchain-1.1.3:
#    -------------------- ------------------- 1/2 [langchain]
#       Successfully uninstalled langchain-1.1.3
#    -------------------- ------------------- 1/2 [langchain]
#    -------------------- ------------------- 1/2 [langchain]
#    -------------------- ------------------- 1/2 [langchain]
#    -------------------- ------------------- 1/2 [langchain]
#    -------------------- ------------------- 1/2 [langchain]
#    -------------------- ------------------- 1/2 [langchain]
#    -------------------- ------------------- 1/2 [langchain]
#    -------------------- ------------------- 1/2 [langchain]
#    -------------------- ------------------- 1/2 [langchain]
#    -------------------- ------------------- 1/2 [langchain]
#    -------------------- ------------------- 1/2 [langchain]
#    -------------------- ------------------- 1/2 [langchain]
#    ---------------------------------------- 2/2 [langchain]
#
# Successfully installed langchain-1.2.3 langchain-core-1.2.7
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser


load_dotenv()
# Out:
# True

# %%
model=ChatOpenAI()

# %%
#1st prompt -> detailed analysis

template1=PromptTemplate(
    input_variables=["topic"],
    template="Provide a detailed analysis of the following text:\n\n{topic}"
)

# %%
#2nd prompt ->summary

template2=PromptTemplate(
    input_variables=["text"],
    template="write a 5 line Summary the following text:\n\n{text}"
)

# %%
parser= StrOutputParser()

# %%
#chain 

chain = template1 | model | parser | template2 | model | parser

# %%
result=chain.invoke({'topic':'black hole'})
print(result)
# Out:
# Summary: Black holes are regions in space with immense gravitational pull that not even light can escape. They form when massive stars collapse, creating a singularity of infinite density and gravity. The concept was first proposed in 1783 and further developed by Einstein. There are different types, including stellar and supermassive black holes. Study of black holes has advanced our understanding of gravity and the universe, leading to fascinating discoveries and captivating the public imagination.
