# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage
from dotenv import load_dotenv

load_dotenv()

model = ChatOpenAI()

# %%
# initialize chat history and append the user and ai messages
chat_history=[ ]

# %%
while True:
    user_input=input("Enter your prompt (or type 'exit' to quit): ")
    print("User Input: ",user_input)
    chat_history.append(user_input)
    if user_input.lower()=='exit' or user_input.lower()=='quit' or user_input.lower()=='stop' or user_input.lower()=='end' or user_input.lower()=='close':
        break
    result=model.invoke(chat_history)
    chat_history.append(result.content) 
    print("AI: ",result.content)
print(chat_history)
# Out:
# User Input:  hi
# AI:  Hello! How can I assist you today?
# User Input:  my name is deepak
# AI:  Hello Deepak! It's nice to meet you. How can I help you today?
# User Input:  what is my name
# AI:  Your name is Deepak as you mentioned earlier! Is there anything else you would like to know or discuss?
# User Input:  close
# ['hi', 'Hello! How can I assist you today?', 'my name is deepak', "Hello Deepak! It's nice to meet you. How can I help you today?", 'what is my name', 'Your name is Deepak as you mentioned earlier! Is there anything else you would like to know or discuss?', 'close']
