# %%
from langchain_core.prompts import ChatPromptTemplate

from langchain_core.messages import HumanMessage, AIMessage, SystemMessage
from langchain_openai import ChatOpenAI

chat_template=ChatPromptTemplate([
    ('system', "You are a helpful {domain} expert."),
    ('human',"Provide detailed information about the topic {topic}.")
])

prompt=chat_template.invoke({
    'domain':'medical',
    'topic':'cardiology'
})

print(prompt)
# Out:
# messages=[SystemMessage(content='You are a helpful medical expert.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Provide detailed information about the topic cardiology.', additional_kwargs={}, response_metadata={})]
