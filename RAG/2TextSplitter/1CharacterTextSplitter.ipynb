# %%
pip install -U langchain-text-splitters
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-text-splitters in c:\users\deepak18\appdata\roaming\python\python313\site-packages (1.1.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-text-splitters) (1.2.7)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.4.5)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (2.11.7)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (4.14.1)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (3.10.18)
# Requirement already satisfied: requests<3,>=2 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (2.32.5)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.23.0)
# Requirement already satisfied: anyio in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (4.9.0)
# Requirement already satisfied: certifi in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (2025.7.9)
# Requirement already satisfied: httpcore==1.* in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from requests<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from requests<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-text-splitters) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_text_splitters import CharacterTextSplitter

# %%
text="""An agent should feel like your chief of staff: you share what you need, it figures out how to get it done, and it improves with feedback. That’s the idea behind Agent Builder.

Start by describing your goal in your own words. Agent Builder figures out the approach, guiding you from initial idea to a deployed agent ready to take on your work. It creates detailed instructions, selects the required tools, and even enlists subagents when required.

It’s different from traditional workflow automations. You don’t need to map every step, tinker with if-this-then-that branching, or babysit dependencies. You just give it feedback like you would a teammate, and the agent learns using its memory. It’s built from the ground up as an agent, with the ability to plan and iterate until it gets the job done, or seek permission before executing sensitive tasks.'"""

# %%
splitter=CharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=10,
    separator=''
)

# %%
result=splitter.split_text(text)

print(result)
# Out:
# ['An agent should feel like your chief of staff: you share what you need, it figures out how to get it', 'to get it done, and it improves with feedback. That’s the idea behind Agent Builder.\n\nStart by desc', 'rt by describing your goal in your own words. Agent Builder figures out the approach, guiding you fr', 'ing you from initial idea to a deployed agent ready to take on your work. It creates detailed instru', 'led instructions, selects the required tools, and even enlists subagents when required.\n\nIt’s differ', 't’s different from traditional workflow automations. You don’t need to map every step, tinker with i', 'ker with if-this-then-that branching, or babysit dependencies. You just give it feedback like you wo', 'ike you would a teammate, and the agent learns using its memory. It’s built from the ground up as an', 'd up as an agent, with the ability to plan and iterate until it gets the job done, or seek permissio', "permission before executing sensitive tasks.'"]
