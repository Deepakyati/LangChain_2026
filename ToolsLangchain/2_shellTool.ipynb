# %% [markdown]
# # Buil in tool - Shell Tool

# %%
from langchain_community.tools import ShellTool

# %%
tool=ShellTool()

result=tool.invoke('whoami')

print(result)
# Out:
# C:\Users\Deepak18\AppData\Roaming\Python\Python313\site-packages\langchain_community\tools\shell\tool.py:33: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(
# Executing command:
#  whoami
# deepak\deepak18
