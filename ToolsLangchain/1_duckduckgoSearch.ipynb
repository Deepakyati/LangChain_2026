# %% [markdown]
# # Built in tool - DuckDuckGo Search

# %%
# !pip install langchain langchain-core langchain-community pydantic duckduckgo-search langchain_experimental
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain in c:\users\deepak18\appdata\roaming\python\python313\site-packages (1.2.3)
# Requirement already satisfied: langchain-core in c:\users\deepak18\appdata\roaming\python\python313\site-packages (1.2.7)
# Requirement already satisfied: langchain-community in c:\users\deepak18\appdata\roaming\python\python313\site-packages (0.4.1)
# Requirement already satisfied: pydantic in c:\users\deepak18\appdata\roaming\python\python313\site-packages (2.11.7)
# Collecting duckduckgo-search
#   Downloading duckduckgo_search-8.1.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: langchain_experimental in c:\users\deepak18\appdata\roaming\python\python313\site-packages (0.4.1)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain) (1.0.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-core) (0.4.5)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-core) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-core) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-core) (4.14.1)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-core) (0.12.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from pydantic) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from pydantic) (0.4.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.3.0)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.1)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.10.18)
# Requirement already satisfied: requests<3,>=2 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.23.0)
# Requirement already satisfied: anyio in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (4.9.0)
# Requirement already satisfied: certifi in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (2025.7.9)
# Requirement already satisfied: httpcore==1.* in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from requests<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from requests<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core) (2.3.0)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-community) (2.0.41)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-community) (2.2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: greenlet>=1 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: click>=8.1.8 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from duckduckgo-search) (8.3.1)
# Collecting primp>=0.15.0 (from duckduckgo-search)
#   Using cached primp-0.15.0-cp38-abi3-win_amd64.whl.metadata (13 kB)
# Collecting lxml>=5.3.0 (from duckduckgo-search)
#   Downloading lxml-6.0.2-cp313-cp313-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: colorama in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from click>=8.1.8->duckduckgo-search) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.3.1)
# Downloading duckduckgo_search-8.1.1-py3-none-any.whl (18 kB)
# Downloading lxml-6.0.2-cp313-cp313-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    --------------- ------------------------ 1.6/4.0 MB 8.1 MB/s eta 0:00:01
#    -------------------------- ------------- 2.6/4.0 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 6.6 MB/s  0:00:00
# Downloading primp-0.15.0-cp38-abi3-win_amd64.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ------------- -------------------------- 1.0/3.1 MB 4.8 MB/s eta 0:00:01
#    ------------------- -------------------- 1.6/3.1 MB 3.6 MB/s eta 0:00:01
#    -------------------------- ------------- 2.1/3.1 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------  3.1/3.1 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 3.5 MB/s  0:00:00
# Installing collected packages: primp, lxml, duckduckgo-search
#
#    ---------------------------------------- 0/3 [primp]
#    ------------- -------------------------- 1/3 [lxml]
#    ------------- -------------------------- 1/3 [lxml]
#    ------------- -------------------------- 1/3 [lxml]
#    ------------- -------------------------- 1/3 [lxml]
#    ------------- -------------------------- 1/3 [lxml]
#    ------------- -------------------------- 1/3 [lxml]
#    ------------- -------------------------- 1/3 [lxml]
#    ------------- -------------------------- 1/3 [lxml]
#    ------------- -------------------------- 1/3 [lxml]
#    -------------------------- ------------- 2/3 [duckduckgo-search]
#    -------------------------- ------------- 2/3 [duckduckgo-search]
#    -------------------------- ------------- 2/3 [duckduckgo-search]
#    ---------------------------------------- 3/3 [duckduckgo-search]
#
# Successfully installed duckduckgo-search-8.1.1 lxml-6.0.2 primp-0.15.0

# %%
from langchain_community.tools import DuckDuckGoSearchRun

# %%
pip install -U ddgs
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ddgs
#   Downloading ddgs-9.10.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: click>=8.1.8 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from ddgs) (8.3.1)
# Requirement already satisfied: primp>=0.15.0 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from ddgs) (0.15.0)
# Requirement already satisfied: lxml>=4.9.4 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from ddgs) (6.0.2)
# Requirement already satisfied: httpx>=0.28.1 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.28.1)
# Collecting fake-useragent>=2.2.0 (from ddgs)
#   Downloading fake_useragent-2.2.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: colorama in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from click>=8.1.8->ddgs) (0.4.6)
# Requirement already satisfied: anyio in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.9.0)
# Requirement already satisfied: certifi in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (2025.7.9)
# Requirement already satisfied: httpcore==1.* in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.0.9)
# Requirement already satisfied: idna in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.16.0)
# Collecting brotli (from httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading brotli-1.2.0-cp313-cp313-win_amd64.whl.metadata (6.3 kB)
# Collecting h2<5,>=3 (from httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting socksio==1.* (from httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading socksio-1.0.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: sniffio>=1.1 in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from anyio->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.3.1)
# Downloading ddgs-9.10.0-py3-none-any.whl (40 kB)
# Downloading fake_useragent-2.2.0-py3-none-any.whl (161 kB)
# Downloading h2-4.3.0-py3-none-any.whl (61 kB)
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Downloading socksio-1.0.0-py3-none-any.whl (12 kB)
# Downloading brotli-1.2.0-cp313-cp313-win_amd64.whl (369 kB)
# Installing collected packages: brotli, socksio, hyperframe, hpack, fake-useragent, h2, ddgs
#
#    ----- ---------------------------------- 1/7 [socksio]
#    ----- ---------------------------------- 1/7 [socksio]
#    ----------- ---------------------------- 2/7 [hyperframe]
#    ----------------- ---------------------- 3/7 [hpack]
#    ----------------- ---------------------- 3/7 [hpack]
#    ---------------------- ----------------- 4/7 [fake-useragent]
#    ---------------------- ----------------- 4/7 [fake-useragent]
#    ---------------------------- ----------- 5/7 [h2]
#    ---------------------------- ----------- 5/7 [h2]
#    ---------------------------- ----------- 5/7 [h2]
#    ---------------------------------- ----- 6/7 [ddgs]
#    ---------------------------------- ----- 6/7 [ddgs]
#    ---------------------------------- ----- 6/7 [ddgs]
#    ---------------------------------- ----- 6/7 [ddgs]
#    ---------------------------------- ----- 6/7 [ddgs]
#    ---------------------------------- ----- 6/7 [ddgs]
#    ---------------------------------- ----- 6/7 [ddgs]
#    ---------------------------------- ----- 6/7 [ddgs]
#    ---------------------------