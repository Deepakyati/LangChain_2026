# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

load_dotenv()
# Out:
# True

# %%
model=ChatOpenAI()

# %%
prompt=PromptTemplate(
    template='Generate 5 intresting facts about{topic}',
    input_variables=['topic']
)

# %%
parser=StrOutputParser()

# %%
chain=prompt | model | parser

# %%
result=chain.invoke({'topic':'AI in India'})

# %%
print(result)
# Out:
# 1. India is rapidly emerging as a global leader in AI technology, with companies like Tata Consultancy Services, Wipro, and Infosys investing heavily in AI research and development.
#
# 2. The Indian government has launched several initiatives to promote AI adoption in various sectors, including the National AI Portal, which aims to provide a platform for collaboration between industry, academia, and government.
#
# 3. India's AI workforce is rapidly growing, with the country expected to become one of the largest markets for AI talent by 2021.
#
# 4. AI is being used in various sectors in India, including healthcare, agriculture, finance, and education, to improve efficiency, accuracy, and decision-making.
#
# 5. India has also launched several AI-focused startups that are making significant strides in developing innovative AI solutions for both domestic and international markets.

# %%
pip install grandalf
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting grandalf
#   Downloading grandalf-0.8-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pyparsing in c:\users\deepak18\appdata\roaming\python\python313\site-packages (from grandalf) (3.3.1)
# Downloading grandalf-0.8-py3-none-any.whl (41 kB)
# Installing collected packages: grandalf
# Successfully installed grandalf-0.8
# Note: you may need to restart the kernel to use updated packages.

# %%
chain.get_graph().print_ascii()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 chain.get_graph().print_ascii()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_core\runnables\graph.py:523, in Graph.print_ascii(self)
#     521 def print_ascii(self) -> None:
#     522     """Print the graph as an ASCII art string."""
# --> 523     print(self.draw_ascii())
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_core\runnables\graph.py:516, in Graph.draw_ascii(self)
#     513 # Import locally to prevent circular import
#     514 from langchain_core.runnables.graph_ascii import draw_ascii  # noqa: PLC0415
# --> 516 return draw_ascii(
#     517     {node.id: node.name for node in self.nodes.values()},
#     518     self.edges,
#     519 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_core\runnables\graph_ascii.py:299, in draw_ascii(vertices, edges)
#     296 xlist: list[float] = []
#     297 ylist: list[float] = []
# --> 299 sug = _build_sugiyama_layout(vertices, edges)
#     301 for vertex in sug.g.sV:
#     302     # NOTE: moving boxes w/2 to the left
#     303     xlist.extend(
#     304         (
#     305             vertex.view.xy[0] - vertex.view.w / 2.0,
#     306             vertex.view.xy[0] + vertex.view.w / 2.0,
#     307         )
#     308     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_core\runnables\graph_ascii.py:206, in _build_sugiyama_layout(vertices, edges)
#     204 if not _HAS_GRANDALF:
#     205     msg = "Install grandalf to draw graphs: `pip install grandalf`."
# --> 206     raise ImportError(msg)
#     208 #
#     209 # Just a reminder about naming conventions:
#     210 # +------------X
#    (...)    215 # Y
#     216 #
#     218 vertices_ = {id_: Vertex(f" {data} ") for id_, data in vertices.items()}
#
# ImportError: Install grandalf to draw graphs: `pip install grandalf`.
