# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

load_dotenv()
# Out:
# True

# %%
prompt1=PromptTemplate(
    template='Generate a detailed report on {topic}',
    input_variables=['topic']
)

# %%
prompt2=PromptTemplate(
    template='Generate a 5 pointer summary from the following text: {text}',
    input_variables=['text']
)

# %%
model=ChatOpenAI()

parser=StrOutputParser()

# %%
chain=prompt1 | model | parser | prompt2 | model | parser

result=chain.invoke({'topic': 'AI jobs in 2026'})

print(result)
# Out:
# 1. The field of artificial intelligence (AI) is experiencing rapid growth in 2026, leading to an increasing demand for skilled professionals in various AI-related jobs.
# 2. Machine learning engineers are one of the most in-demand roles in the AI job market, responsible for designing and implementing machine learning algorithms for a wide range of applications.
# 3. Data scientists are sought after for their expertise in analyzing large datasets to extract insights and drive data-driven decision-making in organizations.
# 4. AI researchers and developers are in high demand as companies invest in cutting-edge AI technologies to stay competitive, requiring a deep understanding of AI principles and techniques.
# 5. The job market for AI professionals is thriving, with opportunities for roles such as AI project managers and consultants who provide strategic guidance on the implementation of AI solutions and drive business outcomes.
